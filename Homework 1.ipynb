# %% [markdown]
# # Bài 1:
# Nhập vào số nguyên n, in ra màn hình số gấp đôi của n

# %%
x = int(input())
print(2*x)
# Out:
# 4

# %% [markdown]
# # Bài 2:
#
# Một khu đất hình chữ nhật có chiều rộng a, chiều dài b. Người ra xây một khu vui chơi hình tròn tại vị trí trung tâm khu đất như hình vẽ. Nhập vào a, b.
#
# Hãy tính phần diện tích còn để trồng cây xung quanh là bao nhiêu. Biết pi = 3 14, lấy kết quả đến 2 chữ số phần thập phân.

# %%
a = float(input())
b = float(input())
print(round(a*b-1/4*3.14*a**2, 2))
# Out:
# 0.86

# %% [markdown]
# # Bài 3:
# Viết chương trình nhập vào một “kí tự” c, nếu nó là chữ hoa thì in ra chữ thường tương ứng và ngược lại nếu nó là chữ thường thì in ra chữ hoa tương ứng của nó (xem trước cấu trúc lựa chọn: if….else, ma)

# %%
character = input()
if character.islower():
    print(character.upper())
elif character.isupper():
    print(character.lower())
# Out:
# C

# %%
c = input()
print(chr(ord(c)+32))
# Out:
# b

# %% [markdown]
# # Bài 4:
#
# Viết chương trình nhập vào một “kí tự”, Kiểm tra xem c có phải là kí tự chữ cái không (hoa hoặc thường).
#
# Nếu đúng thì in ra “{c} là kí tu alphabet”, nếu sai in ra “{c} không phải là kí tự alphabet.

# %%
c = input()
if (ord(c) >= 65 and ord(c) <= 90) or (ord(c) >= 97 and ord(c) <= 122):
    print("c là ký tự alphabet")
else:
    print ("c không phải ký tự alphabet")
# Out:
# c không phải ký tự alphabet

# %%
c = input()
if c.isalpha():
    print("Alphabet") 
elif not c.isalpha():
    print("Not Alphabet")
# Out:
# Not Alphabet

# %% [markdown]
# # Bài 5:
#
# Nhập vào (chữ cái hoa A), in ra (chữ cái thường) liền trước (chữ cái a thường) tương ứng của A.
#
# Xét TH khi c = ‘A’ là đặc biệt

# %%
c = input()
if ord(c) == 65 or ord(c) == 90:
    print("Error")
else:
    ord(c) > 65 and ord(c) < 90
    vi_tri = ord(c) + 33
    print(chr(vi_tri))
# Out:
# d

# %%
c = input()
chuoi_hoa = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
chuoi_thuong = "abcdefghijklmnopqrstuvwxyz"
vi_tri = chuoi_hoa.find(c)
if vi_tri == -1 or c == 'A' or c == 'Z':
    print("Error")
else:
    print(chuoi_thuong[vi_tri - 1])
# Out:
# b

# %% [markdown]
# # Bài 6.
#
# Nhập vào 3 số a, b, c. Kiểm tra xem đây có phải là cạnh của 1 tam giác không, nếu đúng thì tính diện tích của tam giác đó, in ra với 1 chữ số phần thập phân, nếu nó không phải 3 cạnh của tam giác thì in ra “Khong phai 3 canh cua tam giac”

# %%
a, b, c = map(float, input().split())
if a+b<=c or a+c<=b or b+c<=a:
    print("Không phải là tam giác")
else:
    p = (a+b+c)/2
    S = (p*(p-a)*(p-b)*(p-c))**0.5
    print(round(S, 1))
# Out:
# 6.0

# %% [markdown]
# # Bài 7:
# Nhập vào một chuỗi gồm các kí tự thường độ dài >=20, in ra chữ cái thứ năm và thứ chín của chuỗi này.

# %%
c = input()
if len(c) < 20:
    print("Error. Fill again:")
else:
    (ord(c) > 64 and ord(c) < 91) or (ord(c) > 96 and ord(c) < 123)
    alphabet = []
    print(alphabet[4])
    print(alphabet[8])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       3     print("Error. Fill again:")
#       4 else:
# ----> 5     (ord(c) > 64 and ord(c) < 91) or (ord(c) > 96 and ord(c) < 123)
#       6     alphabet = []
#       7     print(alphabet[4])
#
# TypeError: ord() expected a character, but string of length 35 found

# %%
c = input("Nhập chuỗi: ")

if len(c) < 20:
    print("Error. Fill again:")
else:
    alphabet = [ch for ch in c if ch.isalpha()]
    
    if len(alphabet) >= 9:
        print("Chữ thứ 5:", alphabet[4])
        print("Chữ thứ 9:", alphabet[8])
    else:
        print("Không đủ chữ cái")
# Out:
# Chữ thứ 5: y
# Chữ thứ 9: c

# %% [markdown]
# # Bài 8:
#
# Nhập vào họ tên chủ hộ và chỉ số điện kế tháng trước và chỉ số điện kế tháng này,
# tính tiền điện tháng này cho hộ biết:
# - Từ 0 – 50kWh: 1.984 đồng/kWh
# - Bậc 2: Từ 51 – 100 kWh: 2.050 đồng/kWh
# - Bậc 3: Từ 101 – 200 kWh: 2.380 đồng/kWh
# - Bậc 4: Từ 201 – 300 kWh: 2.998 đồng/kWh
# - Bậc 5: Từ 301 – 400 kWh: 3.350 đồng/kWh
# - Bậc 6: Từ 401 trở đi kWh: 3.460 đồng/kWh
#
# Tính thêm tiền VAT 8%. Chỉ lấy đến đơn vị đồng
#
# Input Ouput
#
# Ten chu ho: Pham Xuan Toai
# Chi so thang truoc: 1020
# Chi so thang nay: 1070
# Ho va ten: Pham Xuan Toai
# Tien phai tra la: 107136
# Ten chu ho: Nguyen Xuan Long
# Chi so thang truoc: 2097
# Chi so thang nay: 2278
# Ho va ten: Nguyen Xuan Long
# Tien phai tra la: 426038
# Ten chu ho: Nguyen Xuan Hai
# Chi so thang truoc: 2000
# Chi so thang nay: 2586
# Ho va ten: Nguyen Xuan Hai
# Tien phai tra la: 18555

# %%
ten = input("Nhap ten chu ho: ")
cu = int(input("Chi so thang truoc: "))
moi = int(input("Chi so thang nay: "))

kwh = moi - cu
tien = 0

if kwh <= 50:
    tien = kwh * 1984
elif kwh <= 100:
    tien = 50 * 1984 + (kwh - 50) * 2050
elif kwh <= 200:
    tien = 50 * 1984 + 50 * 2050 + (kwh - 100) * 2380
elif kwh <= 300:
    tien = 50 * 1984 + 50 * 2050 + 100 * 2380 + (kwh - 200) * 2998
elif kwh <= 400:
    tien = 50 * 1984 + 50 * 2050 + 100 * 2380 + 100 * 2998 + (kwh - 300) * 3350
else:
    tien = 50 * 1984 + 50 * 2050 + 100 * 2380 + 100 * 2998 + 100 * 3350 + (kwh - 400) * 3460

tien = int(tien * 1.08)

print("Ho va ten:", ten)
print("Tien phai tra la:", tien)
# Out:
# Ho va ten: 123
# Tien phai tra la: 0
